# %% [markdown]
# ## Setup

# %%
# Define the URL of an image we will use later
url = "https://upload.wikimedia.org/wikipedia/commons/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg"

# %%
# Provide a new jpg url
url = "https://picsum.photos/id/237/800/600"

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display, Markdown

load_dotenv()

client = OpenAI()

# %% [markdown]
# ## Generate Text with the API

# %%
# Set the model
MODEL = "gpt-5-nano"

# Define model inputs
INPUT = """
Your task is to write a LinkedIn post that showcases the efforts I have been making to improve my skills in AI.
Write about the latest course I am taking on RAG by Diogo Resende.
Highlight the amazing Prompt Engineering techniques that are helping me 10X my outputs.
Start with a provocative hook.
Keep paragraphs short, with only one sentence each.
"""

INSTRUCTIONS = """
You are a Founder.

Your persona is friendly and funny, with a touch of acidic humor.

Your goal is to engage and connect with your LinkedIn audience.
"""

# %%
# Call the responses endpoint
response = client.responses.create(
    model=MODEL,
    input=INPUT,
    reasoning={
        "effort": "high"
    },
    text = {
        "verbosity": "medium"
    },
    instructions = INSTRUCTIONS
)

# Display the output
display(Markdown(response.output_text))
# Out:
# Stop hoping AI will save your business—start teaching it how to do the heavy lifting.
# I'm deep into the latest RAG course by Diogo Resende to sharpen my AI toolkit.
# RAG, or Retrieval-Augmented Generation, is finally clicking as a practical workflow, not a buzzword.
# The course is unpacking prompt engineering techniques that are 10X-ing my outputs.
# From smarter context handling to modular prompt templates, my prompts now feel like scalable systems.
# I'm learning to craft goal-driven prompts with explicit objectives, use chain-of-thought prompts for debugging, and build guardrails against hallucinations.
# By integrating retrieval with generation, I'm pulling in relevant docs to inform each response—no more guessing.
# Diogo's emphasis on indexing, search strategies, and prompt templates is turning messy data into crisp, actionable insights.
# As a founder, this is a game changer for product insights, customer support automation, and faster decision-making.
# If you're curious about RAG and prompt engineering, consider checking out the course and trying these prompts on your own data.
# I'll keep sharing wins and learnings as I level up from 'prompt tinkerer' to 'prompt architect'.
# And yes, my coffee budget has doubled since I started this—prompts don't write themselves.

# %%
# Explore the output
# response.output[0].content[0].text
response.output[1].content[0].text
# Out:
# "Stop hoping AI will save your business—start teaching it how to do the heavy lifting. \nI'm deep into the latest RAG course by Diogo Resende to sharpen my AI toolkit. \nRAG, or Retrieval-Augmented Generation, is finally clicking as a practical workflow, not a buzzword. \nThe course is unpacking prompt engineering techniques that are 10X-ing my outputs. \nFrom smarter context handling to modular prompt templates, my prompts now feel like scalable systems. \nI'm learning to craft goal-driven prompts with explicit objectives, use chain-of-thought prompts for debugging, and build guardrails against hallucinations. \nBy integrating retrieval with generation, I'm pulling in relevant docs to inform each response—no more guessing. \nDiogo's emphasis on indexing, search strategies, and prompt templates is turning messy data into crisp, actionable insights. \nAs a founder, this is a game changer for product insights, customer support automation, and faster decision-making. \nIf you're curious about RAG and prompt engineering, consider checking out the course and trying these prompts on your own data. \nI'll keep sharing wins and learnings as I level up from 'prompt tinkerer' to 'prompt architect'. \nAnd yes, my coffee budget has doubled since I started this—prompts don't write themselves."

# %% [markdown]
# ## API with Image Inputs
