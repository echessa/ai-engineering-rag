# %%
# Define the URL of an image we will use later
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"

# %%
# Provide a new jpg url
url = "https://picsum.photos/id/237/800/600"

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display, Markdown

load_dotenv()

client = OpenAI()

# %%
# Set the model
MODEL = "gpt-5-nano"

# Define model inputs
INPUT = """
Your task is to write a LinkedIn post that showcases the efforts I have been making to improve my skills in AI.
Write about the latest course I am taking on RAG by Diogo Resende.
Highlight the amazing Prompt Engineering techniques that are helping me 10X my outputs.
Start with a provocative hook.
Keep paragraphs short, with only one sentence each.
"""

INSTRUCTIONS = """
You are a Founder.

Your persona is friendly and funny, with a touch of acidic humor.

Your goal is to engage and connect with your LinkedIn audience.
"""

# %%
# Call the responses endpoint
response = client.responses.create(
    model=MODEL,
    input=INPUT,
    reasoning={
        "effort": "high"
    },
    text = {
        "verbosity": "medium"
    },
    instructions = INSTRUCTIONS
)

# Display the output
display(Markdown(response.output_text))
# Out:
# RAG isn't a buzzword—it's the turbocharger your AI strategy has been begging for.
# I'm currently taking Diogo Resende's RAG course to level up my AI game as a founder.
# The course dives deep into Retrieval-Augmented Generation (RAG), embeddings, vector stores, and wiring live retrieval into prompts.
# Prompt engineering techniques like chain-of-thought prompts, few-shot demonstrations, and robust templates are turning chaos into clever outputs.
# These techniques are 10X-ing my outputs by boosting relevance, reducing hallucinations, and speeding up iteration.
# I now design prompts that fetch domain docs on the fly and re-rank results before I see the answer.
# Chunking long documents, crafting precise prompts, and adding guardrails keeps me from chasing rabbits.
# If you want faster, smarter AI in practice, this course is a masterclass you can't miss.
# Let's connect and swap notes on prompts that work and those that flop.
# Here’s to shipping more value with fewer excuses and more caffeinated clarity.
